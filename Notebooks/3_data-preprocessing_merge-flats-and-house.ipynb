# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('data/flats_cleaned.csv')
houses = pd.read_csv('data/house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                              property_name property_type  \
# 0          4 BHK Flat in Sector 69 Gurgaon          flat
# 1  4 Bedroom House for sale in Palam Vihar         house
# 2          3 BHK Flat in Sector 52 Gurgaon          flat
# 3          4 BHK Flat in Sector 69 Gurgaon          flat
# 4                      2 BHK Flat in Sohna          flat
#
#                       society  price  price_per_sqft    area  \
# 0                tulip violet   1.90          9452.0  2010.0
# 1                 independent   6.00         20000.0  3000.0
# 2  shree kirpalu gi sector 52   1.45          7631.0  1900.0
# 3                tulip violet   1.90          9452.0  2010.0
# 4                  mvn athens   0.25          5198.0   481.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 2010(186.74 sq.m.)Carpet a...        4         4
# 1                  Built Up area: 333 (278.43 sq.m.)        4         4
# 2  Super Built up area 1900(176.52 sq.m.)Built Up...        3         3
# 3             Super Built up area 2010(186.74 sq.m.)        4         4
# 4                   Built Up area: 481 (44.69 sq.m.)        2         2
#
#   balcony additionalRoom                                       address  \
# 0       2     store room           Sector 69 Gurgaon, Gurgaon, Haryana
# 1       1  not available    Palam Vihar, Palam Vihar, Gurgaon, Haryana
# 2      3+         others  Gurgaon, Sector 52 Gurgaon, Gurgaon, Haryana
# 3       2  not available           Sector 69 Gurgaon, Gurgaon, Haryana
# 4       0  not available       Sohna Sector 5, Sohna, Gurgaon, Haryana
#
#    floorNum      facing    agePossession  \
# 0       6.0        West  1 to 5 Year Old
# 1       2.0         NaN  1 to 5 Year Old
# 2       7.0        West  1 to 5 Year Old
# 3       0.0  South-West  1 to 5 Year Old
# 4       0.0         NaN  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 1                                                NaN
# 2  ['Sector 54 chowk metro station', 'Sector metr...
# 3  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 4  ['SBI ATM', 'Axis bank ATM', 'UCO bank ATM', '...
#
#                                          description  \
# 0  This 4 bhk apartment is available for sale in ...
# 1  4bhk villa for resale in palam vihar palam vih...
# 2  Brokers please excuse. Located in the popular ...
# 3  This lovely 4 bhk apartment/flat with extended...
# 4  Best in class property available at sector 5 s...
#
#                                       furnishDetails  \
# 0  ['1 Exhaust Fan', '1 Modular Kitchen', 'No AC'...
# 1                                                NaN
# 2  ['4 Fan', '1 Exhaust Fan', '3 Geyser', '21 Lig...
# 3  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 4  ['3 Fan', '5 Light', '1 Modular Kitchen', 'No ...
#
#                                             features  \
# 0  ['Water purifier', 'Centrally Air Conditioned'...
# 1                                                NaN
# 2  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 4  ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction4 out of...
# 1  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 2  ['Environment4 out of 5', 'Lifestyle5 out of 5...
# 3  ['Green Area5 out of 5', 'Construction4 out of...
# 4  ['Green Area4 out of 5', 'Construction4 out of...

# %%
df.to_csv('data/gurgaon_properties.csv',index=False)
